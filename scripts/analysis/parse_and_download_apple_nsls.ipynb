# %%
# parse apple nsl pages given the directory
def parse_nsl_pages_and_extract_urls(data_dir):
    files = sorted(os.listdir(data_dir))
    files = [f for f in files if '.html' in f]
    
    # Save all links
    all_urls = []
    for f in files:
        print('processing ' + f)
        # read the raw html
        with open("{}/{}".format(data_dir, f)) as fin:
            html = fin.read()
        # parse html
        soup = BeautifulSoup(html)
        
        # find the table that list nsl letters
        table = soup.find_all('table', class_='transparency-table no-header large-12')
        # not all pages contain nsl pdfs
        if len(table) == 0:
            continue
        else:
            # find the table that contains nsl pdfs
            table = table[-1]
        
        # record data for each nsl letter
        nsl_file_number = None
        nsl_file_url = None
        nsl_date = None
        nsl_release_date = None
        nsl_release_url = None
    
        idx = 0
        for td in table.find_all('td'):
            if td.text.strip() == "NSL":
                continue
            if td.text.strip() == "Issued Date":
                continue
            if td.text.strip() == "Non-Disclosure Released Date":
                continue
            if idx % 3 == 0:
                nsl_file_number = td.text
                nsl_file_url = td.find('a', href=True)['href']
                all_urls.append("https://www.apple.com{}".format(nsl_file_url))
            if idx % 3 == 1:
                nsl_date = td.text
            if idx % 3 == 2:
                nsl_release_date = td.text
            idx += 1
                
    print('total urls: {}'.format(len(all_urls)))
    return all_urls

def download_nsl_urls(data_dir, all_urls):
    for url in all_urls:
        print(url)
        response = requests.get(url)
        with open("{}/{}".format(data_dir, url.split("/")[-1]), 'wb') as f:
            f.write(response.content)
        print(f"Downloaded {url.split('/')[-1]}")
        time.sleep(1)

# %%
import os
from bs4 import BeautifulSoup
import requests
import time

# Directory where we store all html pages that contain links to nsl
DATA_DIR = "../../data/raw/apple_nsl_pages"
# Get urls for all apple pdfs
extracted_urls = parse_nsl_pages_and_extract_urls(DATA_DIR)

# Download data
DATA_DIR = "../../data/raw/nsl/apple"
download_nsl_urls(DATA_DIR, extracted_urls)
# Out:
# processing apple_nsl_page10_accessed_03012024.html
# processing apple_nsl_page11_accessed_03012024.html
# processing apple_nsl_page12_accessed_03012024.html
# processing apple_nsl_page13_accessed_03012024.html
# processing apple_nsl_page14_accessed_03012024.html
# processing apple_nsl_page15_accessed_03012024.html
# processing apple_nsl_page16_accessed_03012024.html
# processing apple_nsl_page17_accessed_03012024.html
# processing apple_nsl_page18_accessed_03012024.html
# processing apple_nsl_page19_accessed_03012024.html
# processing apple_nsl_page1_accessed_03012024.html
# processing apple_nsl_page2_accessed_03012024.html
# processing apple_nsl_page3_accessed_03012024.html
# processing apple_nsl_page4_accessed_03012024.html
# processing apple_nsl_page5_accessed_03012024.html
# processing apple_nsl_page6_accessed_03012024.html
# processing apple_nsl_page7_accessed_03012024.html
# processing apple_nsl_page8_accessed_03012024.html
# processing apple_nsl_page9_accessed_03012024.html
# total urls: 44
# https://www.apple.com/legal/transparency/pdf/NSL-17-435681.pdf
# Downloaded NSL-17-435681.pdf
# https://www.apple.com/legal/transparency/pdf/NSL